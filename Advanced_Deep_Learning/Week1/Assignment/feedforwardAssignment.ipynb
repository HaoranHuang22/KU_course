# %%
import torch
import torch.nn as nn
import torch.utils.data as data
from torch import Tensor
from torchsummary import summary
import numpy as np
import matplotlib.pyplot as plt

# %%
print("Using torch", torch.__version__)
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu") # prefer gpu
print("Device", device)
# Out:
# Using torch 1.13.1
# Device cpu

# %%
class XORDataset(data.Dataset):
    def __init__(self, size, std=0.1, device=device):
        """Make a random XOR data set.

        Args:
            size: Number of data points we want to generate
            std: Standard deviation of the noise (see generate_continuous_xor function)
        """
        super().__init__()
        self.size = size
        self.std = std
        self.generate_continuous_xor()

    def generate_continuous_xor(self):
        # Each data point in the XOR dataset has two variables, x and y, that can be either 0 or 1
        # The label is their XOR combination, i.e. 1 if only x or only y is 1 while the other is 0.
        # If x=y, the label is 0.
        data = torch.randint(low=0, high=2, size=(self.size, 2), dtype=torch.float32)
        label = (data.sum(dim=1) == 1).to(torch.long)
        # To make it slightly more challenging, we add a bit of gaussian noise to the data points.
        data += self.std * torch.randn(data.shape)
        # Move data to GPU if relevant
        self.data = data.to(device)
        self.label = label.to(device)

    def __len__(self):
        # Number of data point we have. Alternatively self.data.shape[0], or self.label.shape[0]
        return self.size

    def __getitem__(self, idx):
        # Return the idx-th data point of the dataset
        # If we have multiple things to return (data point and label), we can return them as tuple
        data_point = self.data[idx]
        data_label = self.label[idx]
        return data_point, data_label

    def toNumpy(self): 
        return (self.data.cpu().numpy(), self.label.cpu().numpy()) # must be on cpuX to convert to numpy

# %%
def visualize_binary_samples(dataset):
    """visualize a data set with binary labels.

    Args:
        data: the data set as, e.g., generated by XORDataset
    """
    (data,label) = dataset.toNumpy()
    data_0 = data[label == 0]
    data_1 = data[label == 1]

    plt.figure(figsize=(4, 4))
    plt.scatter(data_0[:, 0], data_0[:, 1], edgecolor="#333", label="Class 0")
    plt.scatter(data_1[:, 0], data_1[:, 1], edgecolor="#333", label="Class 1")
    plt.title("Dataset samples")
    plt.ylabel(r"$x_2$")
    plt.xlabel(r"$x_1$")
    plt.legend()

dataset = XORDataset(size=200)
print("Size of dataset:", len(dataset))
print("Data point 0:", dataset[0])
visualize_binary_samples(dataset)
plt.show()
# Out:
# Size of dataset: 200
# Data point 0: (tensor([0.8584, 0.0210]), tensor(1))

# %%
class SimpleClassifier(nn.Module):
    def __init__(self, src, tg, depth, width, device=device):
        """Make a convolutional neural network. Last layer uses the identity transfer function, the rest use the tanh.

        Args:
            src: The number of input nodes
            tg: The number of output nodes
            depth: The number of hidden layers
            width: The width of the hidden layers
        """      
        super().__init__()

        self.enc_sizes = [src, tg, depth, width]


        ###############################################################################################
        # Assignment: replace self.model with your code for a network src-width-width-...-tg network
        ###############################################################################################
        if depth == 0:

            functionLst = [nn.Linear(src, tg), nn.Identity()]

        else:
            
            functionLst = [nn.Linear(src, width), nn.Tanh()]
            for i in range(depth-1):
                functionLst.append(nn.Linear(width, width))
                functionLst.append(nn.Tanh())
            functionLst.append(nn.Linear(width, tg))
            functionLst.append(nn.Identity())
            
        self.model = nn.Sequential(*functionLst) #unpacking with the '*' operator

        # Move data to GPU if relevant
        self.model.to(device)

    def forward(self, x):
        x = self.model(x)
        x = x.squeeze(dim=1) # flat

        return x

def train_model(model, optimizer, data_loader, loss_module, num_epochs=100):
    """Train a model.

    Args:
        model: The model to train
        optimizer: The optimizer to use
        data_loader: The function to load the data
        loss_module: The function to evaluate the loss function
        num_epochs: The number of epochs to train
    """      
    # Set model to train mode
    model.train()

    # Training loop
    for epoch in range(num_epochs):
        for data_inputs, data_labels in data_loader:
            # Step 1: Run the model on the input data
            preds = model(data_inputs)
            #preds = preds.squeeze(dim=1)  # Output is [Batch size, 1], but we want [Batch size]

            # Step 2: Calculate the loss
            loss = loss_module(preds, data_labels.float())

            # Step 3: Perform backpropagation
            # Before calculating the gradients, we need to ensure that they are all zero.
            # The gradients would not be overwritten, but actually added to the existing ones.
            optimizer.zero_grad()
            # Perform backpropagation
            loss.backward()

            # Step 4: Update the parameters
            optimizer.step()

def eval_model(model, data_loader, loss_module):
    """Evaluate a model.

    Args:
        model: A (trained) model
        data_loader: The function to load the data
    """      
    model.eval()  # Set model to eval mode
    true_preds, num_preds = 0.0, 0.0

    with torch.no_grad():  # Deactivate gradients for the following code
        for data_inputs, data_labels in data_loader:
            preds = model(data_inputs)
            loss = loss_module(preds, data_labels.float()) # Calculate the loss

            preds = torch.sigmoid(preds)  # Sigmoid to map predictions between 0 and 1
            pred_labels = (preds >= 0.5).long()  # Binarize predictions to 0 and 1

            # Keep records of predictions for the accuracy metric (true_preds=TP+TN, num_preds=TP+TN+FP+FN)
            true_preds += (pred_labels == data_labels).sum()
            num_preds += data_labels.shape[0]

    acc = true_preds / num_preds
    return acc, loss

# %%
###############################################################################################
# Assignment: replace the following with code that trains your networks repeatedly on the same 
# XORDataset for a range of depths and widths, e.g., depths and widths in the range range(4) 
# and each repeated 3 times.
###############################################################################################

loss_module = nn.BCEWithLogitsLoss()
train_dataset = XORDataset(size=1000)
train_data_loader = data.DataLoader(train_dataset, batch_size=128, shuffle=True)
test_dataset = XORDataset(size=500)
# drop_last -> Don't drop the last batch although it is smaller than 128
test_data_loader = data.DataLoader(test_dataset, batch_size=128, shuffle=False, drop_last=False)


# Setup a feed-forward network with variable width and depth
src = 2
tg = 1
depth = [0, 1, 2, 3]
width = [1, 2, 3]
repeated_times = 3

def combination_depths_widths(src, tg, depth, width):
    loss_list = []
    for d in depth:
        for w in width:
            model = SimpleClassifier(src = src, tg =tg, depth = d, width = w)
            summary(model, input_size=(2,))
            optimizer = torch.optim.SGD(model.parameters(), lr=0.1)
            train_model(model, optimizer, train_data_loader, loss_module, num_epochs=200)
            
            acc, loss = eval_model(model, test_data_loader, loss_module)
            loss_list.append(loss.item())
            print("depth: ", d, "width: ", w, "acc: ", acc.item(), "loss:", loss.item())

    return loss_list

# repeat the experiment 3 times
loss_array = np.zeros((repeated_times, len(depth)*len(width)))
for i in range(repeated_times):
    print("repeated time:", i)
    loss_array[i,:] = combination_depths_widths(src, tg, depth, width)

# calculate the mean and std of the loss
loss_mean = np.mean(loss_array, axis = 0)
loss_std = np.std(loss_array, axis = 0)
print("loss mean:", loss_mean)
print("loss std:", loss_std)
# Out:
# repeated time: 0
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 1]               3
#           Identity-2                    [-1, 1]               0
# ================================================================
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# depth:  0 width:  1 acc:  0.49399998784065247 loss: 0.6919286847114563
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 1]               3
#           Identity-2                    [-1, 1]               0
# ================================================================
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# depth:  0 width:  2 acc:  0.4959999918937683 loss: 0.6918134093284607
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 1]               3
#           Identity-2                    [-1, 1]               0
# ================================================================
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# depth:  0 width:  3 acc:  0.49399998784065247 loss: 0.691956102848053
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 1]               3
#               Tanh-2                    [-1, 1]               0
#             Linear-3                    [-1, 1]               2
#           Identity-4                    [-1, 1]               0
# ================================================================
# Total params: 5
# Trainable params: 5
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# depth:  1 width:  1 acc:  0.7639999985694885 loss: 0.5176440477371216
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 2]               6
#               Tanh-2                    [-1, 2]               0
#             Linear-3                    [-1, 1]               3
#           Identity-4                    [-1, 1]               0
# ================================================================
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# depth:  1 width:  2 acc:  1.0 loss: 0.06813636422157288
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 3]               9
#               Tanh-2                    [-1, 3]               0
#             Linear-3                    [-1, 1]               4
#           Identity-4                    [-1, 1]               0
# ================================================================
# Total params: 13
# Trainable params: 13
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# depth:  1 width:  3 acc:  1.0 loss: 0.07169098407030106
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 1]               3
#               Tanh-2                    [-1, 1]               0
#             Linear-3                    [-1, 1]               2
#               Tanh-4                    [-1, 1]               0
#             Linear-5                    [-1, 1]               2
#           Identity-6                    [-1, 1]               0
# ================================================================
# Total params: 7
# Trainable params: 7
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# depth:  2 width:  1 acc:  0.7639999985694885 loss: 0.46750929951667786
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 2]               6
#               Tanh-2                    [-1, 2]               0
#             Linear-3                    [-1, 2]               6
#               Tanh-4                    [-1, 2]               0
#             Linear-5                    [-1, 1]               3
#           Identity-6                    [-1, 1]               0
# ================================================================
# Total params: 15
# Trainable params: 15
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# depth:  2 width:  2 acc:  1.0 loss: 0.018525542691349983
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 3]               9
#               Tanh-2                    [-1, 3]               0
#             Linear-3                    [-1, 3]              12
#               Tanh-4                    [-1, 3]               0
#             Linear-5                    [-1, 1]               4
#           Identity-6                    [-1, 1]               0
# ================================================================
# Total params: 25
# Trainable params: 25
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# depth:  2 width:  3 acc:  1.0 loss: 0.19597028195858002
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 1]               3
#               Tanh-2                    [-1, 1]               0
#             Linear-3                    [-1, 1]               2
#               Tanh-4                    [-1, 1]               0
#             Linear-5                    [-1, 1]               2
#               Tanh-6                    [-1, 1]               0
#             Linear-7                    [-1, 1]               2
#           Identity-8                    [-1, 1]               0
# ================================================================
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# depth:  3 width:  1 acc:  0.7639999985694885 loss: 0.463516503572464
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 2]               6
#               Tanh-2                    [-1, 2]               0
#             Linear-3                    [-1, 2]               6
#               Tanh-4                    [-1, 2]               0
#             Linear-5                    [-1, 2]               6
#               Tanh-6                    [-1, 2]               0
#             Linear-7                    [-1, 1]               3
#           Identity-8                    [-1, 1]               0
# ================================================================
# Total params: 21
# Trainable params: 21
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# depth:  3 width:  2 acc:  0.9959999918937683 loss: 0.28915858268737793
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 3]               9
#               Tanh-2                    [-1, 3]               0
#             Linear-3                    [-1, 3]              12
#               Tanh-4                    [-1, 3]               0
#             Linear-5                    [-1, 3]              12
#               Tanh-6                    [-1, 3]               0
#             Linear-7                    [-1, 1]               4
#           Identity-8                    [-1, 1]               0
# ================================================================
# Total params: 37
# Trainable params: 37
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# depth:  3 width:  3 acc:  1.0 loss: 0.007881755009293556
# repeated time: 1
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 1]               3
#           Identity-2                    [-1, 1]               0
# ================================================================
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# depth:  0 width:  1 acc:  0.49399998784065247 loss: 0.6918865442276001
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 1]               3
#           Identity-2                    [-1, 1]               0
# ================================================================
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# depth:  0 width:  2 acc:  0.49399998784065247 loss: 0.691993772983551
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 1]               3
#           Identity-2                    [-1, 1]               0
# ================================================================
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# depth:  0 width:  3 acc:  0.49399998784065247 loss: 0.6919493675231934
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 1]               3
#               Tanh-2                    [-1, 1]               0
#             Linear-3                    [-1, 1]               2
#           Identity-4                    [-1, 1]               0
# ================================================================
# Total params: 5
# Trainable params: 5
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# depth:  1 width:  1 acc:  0.7639999985694885 loss: 0.48007339239120483
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 2]               6
#               Tanh-2                    [-1, 2]               0
#             Linear-3                    [-1, 1]               3
#           Identity-4                    [-1, 1]               0
# ================================================================
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# depth:  1 width:  2 acc:  0.7639999985694885 loss: 0.34794679284095764
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 3]               9
#               Tanh-2                    [-1, 3]               0
#             Linear-3                    [-1, 1]               4
#           Identity-4                    [-1, 1]               0
# ================================================================
# Total params: 13
# Trainable params: 13
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# depth:  1 width:  3 acc:  1.0 loss: 0.05180000886321068
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 1]               3
#               Tanh-2                    [-1, 1]               0
#             Linear-3                    [-1, 1]               2
#               Tanh-4                    [-1, 1]               0
#             Linear-5                    [-1, 1]               2
#           Identity-6                    [-1, 1]               0
# ================================================================
# Total params: 7
# Trainable params: 7
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# depth:  2 width:  1 acc:  0.49399998784065247 loss: 0.6924921274185181
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 2]               6
#               Tanh-2                    [-1, 2]               0
#             Linear-3                    [-1, 2]               6
#               Tanh-4                    [-1, 2]               0
#             Linear-5                    [-1, 1]               3
#           Identity-6                    [-1, 1]               0
# ================================================================
# Total params: 15
# Trainable params: 15
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# depth:  2 width:  2 acc:  1.0 loss: 0.01876271329820156
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 3]               9
#               Tanh-2                    [-1, 3]               0
#             Linear-3                    [-1, 3]              12
#               Tanh-4                    [-1, 3]               0
#             Linear-5                    [-1, 1]               4
#           Identity-6                    [-1, 1]               0
# ================================================================
# Total params: 25
# Trainable params: 25
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# depth:  2 width:  3 acc:  1.0 loss: 0.0072745974175632
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 1]               3
#               Tanh-2                    [-1, 1]               0
#             Linear-3                    [-1, 1]               2
#               Tanh-4                    [-1, 1]               0
#             Linear-5                    [-1, 1]               2
#               Tanh-6                    [-1, 1]               0
#             Linear-7                    [-1, 1]               2
#           Identity-8                    [-1, 1]               0
# ================================================================
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# depth:  3 width:  1 acc:  0.7639999985694885 loss: 0.47358983755111694
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 2]               6
#               Tanh-2                    [-1, 2]               0
#             Linear-3                    [-1, 2]               6
#               Tanh-4                    [-1, 2]               0
#             Linear-5                    [-1, 2]               6
#               Tanh-6                    [-1, 2]               0
#             Linear-7                    [-1, 1]               3
#           Identity-8                    [-1, 1]               0
# ================================================================
# Total params: 21
# Trainable params: 21
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# depth:  3 width:  2 acc:  1.0 loss: 0.007214480545371771
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 3]               9
#               Tanh-2                    [-1, 3]               0
#             Linear-3                    [-1, 3]              12
#               Tanh-4                    [-1, 3]               0
#             Linear-5                    [-1, 3]              12
#               Tanh-6                    [-1, 3]               0
#             Linear-7                    [-1, 1]               4
#           Identity-8                    [-1, 1]               0
# ================================================================
# Total params: 37
# Trainable params: 37
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# depth:  3 width:  3 acc:  1.0 loss: 0.004831226076930761
# repeated time: 2
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 1]               3
#           Identity-2                    [-1, 1]               0
# ================================================================
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# depth:  0 width:  1 acc:  0.4959999918937683 loss: 0.6917914748191833
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 1]               3
#           Identity-2                    [-1, 1]               0
# ================================================================
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# depth:  0 width:  2 acc:  0.49399998784065247 loss: 0.691864550113678
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 1]               3
#           Identity-2                    [-1, 1]               0
# ================================================================
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# depth:  0 width:  3 acc:  0.4959999918937683 loss: 0.6917601823806763
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 1]               3
#               Tanh-2                    [-1, 1]               0
#             Linear-3                    [-1, 1]               2
#           Identity-4                    [-1, 1]               0
# ================================================================
# Total params: 5
# Trainable params: 5
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# depth:  1 width:  1 acc:  0.7639999985694885 loss: 0.4796229302883148
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 2]               6
#               Tanh-2                    [-1, 2]               0
#             Linear-3                    [-1, 1]               3
#           Identity-4                    [-1, 1]               0
# ================================================================
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# depth:  1 width:  2 acc:  0.7639999985694885 loss: 0.3654944896697998
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 3]               9
#               Tanh-2                    [-1, 3]               0
#             Linear-3                    [-1, 1]               4
#           Identity-4                    [-1, 1]               0
# ================================================================
# Total params: 13
# Trainable params: 13
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# depth:  1 width:  3 acc:  1.0 loss: 0.04976555332541466
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 1]               3
#               Tanh-2                    [-1, 1]               0
#             Linear-3                    [-1, 1]               2
#               Tanh-4                    [-1, 1]               0
#             Linear-5                    [-1, 1]               2
#           Identity-6                    [-1, 1]               0
# ================================================================
# Total params: 7
# Trainable params: 7
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# depth:  2 width:  1 acc:  0.7580000162124634 loss: 0.6522582769393921
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 2]               6
#               Tanh-2                    [-1, 2]               0
#             Linear-3                    [-1, 2]               6
#               Tanh-4                    [-1, 2]               0
#             Linear-5                    [-1, 1]               3
#           Identity-6                    [-1, 1]               0
# ================================================================
# Total params: 15
# Trainable params: 15
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# depth:  2 width:  2 acc:  1.0 loss: 0.012476014904677868
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 3]               9
#               Tanh-2                    [-1, 3]               0
#             Linear-3                    [-1, 3]              12
#               Tanh-4                    [-1, 3]               0
#             Linear-5                    [-1, 1]               4
#           Identity-6                    [-1, 1]               0
# ================================================================
# Total params: 25
# Trainable params: 25
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# depth:  2 width:  3 acc:  1.0 loss: 0.018340636044740677
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 1]               3
#               Tanh-2                    [-1, 1]               0
#             Linear-3                    [-1, 1]               2
#               Tanh-4                    [-1, 1]               0
#             Linear-5                    [-1, 1]               2
#               Tanh-6                    [-1, 1]               0
#             Linear-7                    [-1, 1]               2
#           Identity-8                    [-1, 1]               0
# ================================================================
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# depth:  3 width:  1 acc:  0.75 loss: 0.47589194774627686
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 2]               6
#               Tanh-2                    [-1, 2]               0
#             Linear-3                    [-1, 2]               6
#               Tanh-4                    [-1, 2]               0
#             Linear-5                    [-1, 2]               6
#               Tanh-6                    [-1, 2]               0
#             Linear-7                    [-1, 1]               3
#           Identity-8                    [-1, 1]               0
# ================================================================
# Total params: 21
# Trainable params: 21
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# depth:  3 width:  2 acc:  1.0 loss: 0.010386318899691105
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                    [-1, 3]               9
#               Tanh-2                    [-1, 3]               0
#             Linear-3                    [-1, 3]              12
#               Tanh-4                    [-1, 3]               0
#             Linear-5                    [-1, 3]              12
#               Tanh-6                    [-1, 3]               0
#             Linear-7                    [-1, 1]               4
#           Identity-8                    [-1, 1]               0
# ================================================================
# Total params: 37
# Trainable params: 37
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------
# depth:  3 width:  3 acc:  0.9980000257492065 loss: 0.3140372633934021
# loss mean: [0.6918689  0.69189058 0.69188855 0.49244679 0.26052588 0.05775218
#  0.60408657 0.01658809 0.07386184 0.47099943 0.10225313 0.10891675]
# loss std: [5.73881205e-05 7.58983078e-05 9.08119010e-05 1.78181008e-02
#  1.36228424e-01 9.89115439e-03 9.79615686e-02 2.90928806e-03
#  8.64618154e-02 5.37404655e-03 1.32168458e-01 1.45047454e-01]

# %%
# Out:
# (3, 12)
